# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from tickers import getTickerList, getCandlePatternList
from datemodule import getDateRange
from indicators import ChannelBreakoutIndicator
from datasource import getFullData
import pandas

# %%
import talib
import pandas_ta as ta
from tqdm import tqdm

tickers = getTickerList(all=True)
tickerShortlist = {}
tickerShortlistData = {}

for i in tqdm(range(len(tickers))):
    ticker = tickers[i]
    resultDict = {}

    # Fetch Data
    startDate, endDate = getDateRange('3m')
    df = getFullData(ticker, startDate, endDate)
    
    candleIndex = len(df)-1
    
    # RSI
    df['RSI'] = ta.rsi(df.Close, length=14)

    # Candlestick Pattern Recognition
    op = df['Open']
    hi = df['High']
    lo = df['Low']
    cl = df['Close']
    for pattern in getCandlePatternList(all=False):
        sig = getattr(talib, pattern)(op, hi, lo, cl)[candleIndex]
        if sig != 0:
            resultDict[pattern] = sig

    # Collect Signals
    if (len(resultDict) != 0):
        resultDict["RSI"] = df['RSI'][candleIndex]
        tickerShortlist[ticker] = resultDict
# Out:
# 100%|██████████| 96/96 [00:46<00:00,  2.04it/s]

# %%
shortlisted = pandas.DataFrame(tickerShortlist).transpose()
entries = []
for index, row in shortlisted.iterrows():
    entries.append(row.count())
shortlisted["ENTRIES"] = entries
shortlisted.sort_values(by='ENTRIES', ascending = False)
# Out:
#             CDLSPINNINGTOP        RSI  CDLDARKCLOUDCOVER  CDLDOJI  \
# SHREECEM            -100.0  37.683348                NaN    100.0
# HINDUNILVR          -100.0  58.614507                NaN    100.0
# CIPLA                100.0  61.138692                NaN      NaN
# PIDILITIND          -100.0  41.511060                NaN    100.0
# HDFCAMC              100.0  74.929096                NaN    100.0
# LT                     NaN  69.779291                NaN    100.0
# ADANIENT            -100.0  53.563295                NaN    100.0
# JSWSTEEL            -100.0  73.512170                NaN    100.0
# ADANIPORTS           100.0  54.452558                NaN    100.0
# ADANIGREEN           100.0  46.095481                NaN      NaN
# INFY                   NaN  63.243719                NaN    100.0
# BRITANNIA            100.0  64.485427                NaN    100.0
# DIVISLAB               NaN  55.495765                NaN      NaN
# ASIANPAINT          -100.0  67.194354                NaN      NaN
# CANBK                100.0  65.238514                NaN      NaN
# APOLLOHOSP             NaN  61.855798                NaN      NaN
# LTIM                   NaN  66.972700                NaN      NaN
# TATAMOTORS             NaN  67.816350                NaN      NaN
# SRF                    NaN  30.635084                NaN      NaN
# AWL                    NaN  43.351854                NaN      NaN
# TCS                    NaN  57.998471                NaN      NaN
# BOSCHLTD            -100.0  54.973952                NaN      NaN
# COALINDIA           -100.0  54.869905                NaN      NaN
# INDUSINDBK             NaN  67.785674                NaN      NaN
# HDFCBANK             100.0  76.080971                NaN      NaN
# GRASIM                 NaN  55.251315             -100.0      NaN
# ITC                  100.0  73.249948                NaN      NaN
# BPCL                 100.0  60.393808                NaN      NaN
# CHOLAFIN             100.0  74.155308                NaN      NaN
# SBIN                 100.0  63.198882                NaN      NaN
# HDFC                 100.0  80.240441                NaN      NaN
# GAIL                   NaN  52.909717                NaN      NaN
# ICICIBANK           -100.0  58.984350                NaN      NaN
# BANKBARODA           100.0  70.631739                NaN      NaN
# MUTHOOTFIN             NaN  73.166726                NaN      NaN
# ACC                    NaN  52.103008                NaN      NaN
# DLF                    NaN  57.120632                NaN      NaN
# HAVELLS                NaN  39.876520                NaN      NaN
# INDUSTOWER             NaN  52.773023                NaN      NaN
# ZOMATO                 NaN  58.222622                NaN      NaN
# MARICO                 NaN  45.905964                NaN      NaN
# SUNPHARMA              NaN  68.786280                NaN      NaN
#
#             CDLHANGINGMAN  CDLENGULFING  CDLEVENINGSTAR  CDLHARAMI  \
# SHREECEM              NaN           NaN             NaN        NaN
# HINDUNILVR            NaN           NaN             NaN        NaN
# CIPLA                 NaN           NaN             NaN      100.0
# PIDILITIND            NaN           NaN             NaN        NaN
# HDFCAMC               NaN           NaN             NaN        NaN
# LT                    NaN           NaN             NaN      100.0
# ADANIENT              NaN           NaN             NaN        NaN
# JSWSTEEL              NaN           NaN             NaN        NaN
# ADANIPORTS            NaN           NaN             NaN        NaN
# ADANIGREEN            NaN           NaN             NaN      100.0
# INFY               -100.0           NaN             NaN        NaN
# BRITANNIA             NaN           NaN             NaN        NaN
# DIVISLAB              NaN        -100.0             NaN        NaN
# ASIANPAINT            NaN           NaN             NaN        NaN
# CANBK                 NaN           NaN             NaN        NaN
# APOLLOHOSP            NaN           NaN             NaN      100.0
# LTIM                  NaN         100.0             NaN        NaN
# TATAMOTORS            NaN           NaN             NaN      100.0
# SRF                   NaN           NaN             NaN        NaN
# AWL                   NaN           NaN             NaN      100.0
# TCS                   NaN           NaN             NaN      100.0
# BOSCHLTD              NaN           NaN             NaN        NaN
# COALINDIA             NaN           NaN             NaN        NaN
# INDUSINDBK            NaN        -100.0             NaN        NaN
# HDFCBANK              NaN           NaN             NaN        NaN
# GRASIM                NaN           NaN             NaN        NaN
# ITC                   NaN           NaN             NaN        NaN
# BPCL                  NaN           NaN             NaN        NaN
# CHOLAFIN              NaN           NaN             NaN        NaN
# SBIN                  NaN           NaN             NaN        NaN
# HDFC                  NaN           NaN             NaN        NaN
# GAIL               -100.0           NaN             NaN        NaN
# ICICIBANK             NaN           NaN             NaN        NaN
# BANKBARODA            NaN           NaN             NaN        NaN
# MUTHOOTFIN            NaN        -100.0             NaN        NaN
# ACC                   NaN        -100.0             NaN        NaN
# DLF                   NaN        -100.0             NaN        NaN
# HAVELLS               NaN        -100.0             NaN        NaN
# INDUSTOWER            NaN        -100.0             NaN        NaN
# ZOMATO                NaN        -100.0             NaN        NaN
# MARICO                NaN           NaN          -100.0        NaN
# SUNPHARMA             NaN           NaN             NaN      100.0
#
#             CDLMARUBOZU  ENTRIES
# SHREECEM            NaN        3
# HINDUNILVR          NaN        3
# CIPLA               NaN        3
# PIDILITIND          NaN        3
# HDFCAMC             NaN        3
# LT                  NaN        3
# ADANIENT            NaN        3
# JSWSTEEL            NaN        3
# ADANIPORTS          NaN        3
# ADANIGREEN          NaN        3
# INFY                NaN        3
# BRITANNIA           NaN        3
# DIVISLAB            NaN        2
# ASIANPAINT          NaN        2
# CANBK               NaN        2
# APOLLOHOSP          NaN        2
# LTIM                NaN        2
# TATAMOTORS          NaN        2
# SRF              -100.0        2
# AWL                 NaN        2
# TCS                 NaN        2
# BOSCHLTD            NaN        2
# COALINDIA           NaN        2
# INDUSINDBK          NaN        2
# HDFCBANK            NaN        2
# GRASIM              NaN        2
# ITC                 NaN        2
# BPCL                NaN        2
# CHOLAFIN            NaN        2
# SBIN                NaN        2
# HDFC                NaN        2
# GAIL                NaN        2
# ICICIBANK           NaN        2
# BANKBARODA          NaN        2
# MUTHOOTFIN          NaN        2
# ACC                 NaN        2
# DLF                 NaN        2
# HAVELLS             NaN        2
# INDUSTOWER          NaN        2
# ZOMATO              NaN        2
# MARICO              NaN        2
# SUNPHARMA           NaN        2
